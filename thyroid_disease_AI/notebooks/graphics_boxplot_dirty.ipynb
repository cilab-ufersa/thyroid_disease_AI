# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Abrindo dataset
dataset = pd.read_csv('C:\\Users\\caiom\\Desktop\Sist Hypo\\thyroid_disease_AI\\thyroid_disease_AI\\datasets\\hypothyroid\\hypothyroid_dataset_dirty.csv')

dataset.head()
# Out:
#      TT4  TT4 measured  T4U measured  T3 measured    FTI   T3   TSH   T4U  \
# 0  125.0             1             1            1  109.0  2.5  1.30  1.14
# 1   61.0             1             1            1   70.0  1.2  0.72  0.87
# 2   80.0             1             1            1  115.0  0.6  2.20  0.70
# 3  123.0             1             1            1  132.0  2.2  0.60  0.93
# 4   83.0             1             1            1   93.0  1.6  2.40  0.89
#
#    pregnant  I131 treatment  binaryClass
# 0         0               0            1
# 1         0               0            1
# 2         0               0            1
# 3         0               0            1
# 4         0               0            1

# %%
for feature in dataset[:1]:
    dataFrame = pd.DataFrame(dataset[feature])
    dataFrame = dataFrame.astype(float)

    # Criar um boxplot para todas as features no DataFrame 'df'
    plt.figure(figsize=(10, 6))  # Tamanho da figura
    plt.boxplot(dataFrame.values, vert=False)  # Cria o boxplot
    plt.xticks(range(1, len(dataFrame.columns) + 1), dataFrame.columns)  # Rótulos no eixo x
    plt.title('Boxplot de Features')  # Título do gráfico

    plt.show()
